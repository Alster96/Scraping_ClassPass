# %% [markdown]
# Project 1 - Classpass data analysis

# %%
import numpy as np
import pandas as pd
import folium 
from matplotlib import pyplot as plt
plt.style.use('ggplot')


#read in the csv file
df = pd.read_csv('friday_classpass.csv',encoding = 'unicode_escape')
df.sample(5)
# Out:
#                    Title      Instructor Rating  Reviews      Time  Duration  \
# 414      Yoga- All Level      Erika Fury    4.8   1949.0  10:00 am        75
# 1412  Pure Barre Classic    Hannah Dober    4.8  15240.0   4:30 pm        50
# 1269              BYK$20   Eric Lawrence    4.7  10287.0   4:00 pm        45
# 1262     Olaplex Blowout            none    4.8    358.0   4:00 pm        45
# 434           Vinyasa II  Olga Palladino    4.8   9267.0  10:15 am        75
#
#                   Venue          Location  \
# 414        Zen and Yoga      Forest Hills
# 1412         Pure Barre   Upper East Side
# 1269             BYKlyn        Park Slope
# 1262            Glam+Go  Theatre District
# 434   Five Pillars Yoga   Upper East Side
#
#                                         Tags  Price
# 414         Flexibility, Balance, Arms, Yoga      3
# 1412  Flexibility, Balance, Core, Abs, Barre     16
# 1269                         Cardio, Cycling      7
# 1262                                     NaN     41
# 434         Flexibility, Balance, Arms, Yoga      8

# %%
df.dtypes
# Out:
# Title         object
# Instructor    object
# Rating        object
# Reviews       object
# Time          object
# Duration       int64
# Venue         object
# Location      object
# Tags          object
# Price          int64
# dtype: object

# %%
df.columns = df.columns.str.lower() #put all headers to lower case for ease of manipulation

# %%
df = df[~df['instructor'].str.contains("none")] #removes any row which has 'none' in the instructor column

# %%
df = df[~df['rating'].str.contains("none")] #removes any row which has 'none' in the rating column

# %%
df = df[~df['reviews'].str.contains("#VALUE!")] #removes any row which has '#VALUE!' in the reviews column

# %%
(df == "none").any() #check for any none values
# Out:
# title         False
# instructor    False
# rating        False
# reviews       False
# time          False
# duration      False
# venue         False
# location      False
# tags          False
# price         False
# dtype: bool

# %%
df.dropna(inplace = True) #drop all NaN's

# %%
df.isnull().sum().sum() #double check
# Out:
# 0

# %%
df["rating"]=df["rating"].astype(float) #change type

# %%
df["reviews"]=df["reviews"].astype(float) #change type

# %%
df.dtypes
# Out:
# title          object
# instructor     object
# rating        float64
# reviews       float64
# time           object
# duration        int64
# venue          object
# location       object
# tags           object
# price           int64
# dtype: object

# %%
df.corr()
# Out:
#             rating   reviews  duration     price
# rating    1.000000  0.262652 -0.022287  0.267587
# reviews   0.262652  1.000000 -0.199746  0.513789
# duration -0.022287 -0.199746  1.000000 -0.206737
# price     0.267587  0.513789 -0.206737  1.000000

# %%
df
# Out:
#                                                   title          instructor  \
# 0                        Pilates Reformer: Abs Arms Ass          Meg Broome
# 1                                         SKY TING Yoga        Grace Dubery
# 2                                      WundaBar Workout     Marta Picaporte
# 3                                           BigToe Flow    Patrick Rafferty
# 4                             Pilates Reformer: Burnout        Lisa Jantzie
# 5                                          Signature II      Veronika Cohen
# 6                                   Flywheel: Method 45        Cedric Green
# 7                                   EXCEED: The Workout        Jed Cabreira
# 8                    Pilates Reformer: Sculpt + Restore         Heran Haile
# 9                                                barre3        Jenna Muller
# 10                                        ISHTA Vinyasa      Mikaela Soldan
# 11                                                 HIIT       Tatiana Lampa
# 12                                          B3 x Tomíçs       Tomas Rodgers
# 13                                                Cyc45     Michael Clement
# 14                                 SHADOWBOX - STANDARD             Brendan
# 15                                          Heated Flow           Amy Wolfe
# 16                                                  HIT       Scott Freeman
# 17                                  Flywheel: Method 45       Steven Little
# 18                                       UPLIFT EXPRESS         Meg Hopkins
# 19                               Bikram Yoga 60 - Music      Sara Corenzwit
# 20    Strength Training: Lower Body (formerly Glutes...      Lariscy Walker
# 21                                            Body (AM)      Danielle Barry
# 22                                   Adult: Gaga.People       Gaga *Faculty
# 23                                                 LIFT            Jenni M.
# 24                                             BOOTCAMP     Alex R Redelico
# 25                                          Signature I         Sally Glaze
# 26                                             Prenatal        Sonia Reiter
# 27                                  Flywheel: Method 45      Nowani Rattray
# 28                                   FlyBarre: Power 45     Michelle Rubich
# 29                                             All Flow        Natalie Girs
# ...                                                 ...                 ...
# 2429        Ladies Technique and Styling in Cha Cha Cha               Mandy
# 2430                               Restorative w/ Music     Alystyre Julian
# 2431                       Overthrow Underground Boxing           Julian D.
# 2432                              Candlelit Chakra Flow        Lauren Logan
# 2433                                             barre3       Amanda Fruitt
# 2434                              Candlelit Restorative     Donald Johnston
# 2435                          Switch40 - Cardio Circuit        Brian Miller
# 2436                                      Flow + Let Go       Allie Gardner
# 2437          Russian Exotic *PREREQUISITE BEGINNER II*  Casey Leigh Jordan
# 2438                     Adult: Open Level West African     Ismael *Kouyate
# 2439                            Total Body (60 Minutes)     Matthew Griffin
# 2443                             Pilates Machine Class.  Natalie Labellarte
# 2444                              Pilates Machine Class   Cassie Washington
# 2450      Restorative & Yoga Nidra Meditation (Level 1)        Christie Roe
# 2451                            Basic Vinyasa + Restore         Dana Greene
# 2454                                     Flow & Restore      Emily Nachazel
# 2456                                           Hot HIIT       Monique Crous
# 2457                                  Naam Aromatherapy          Dallas Lyn
# 2460                                PELOTON RESERVATION           PELOTON .
# 2463                                  Cardio Kickboxing        Diego Araujo
# 2464                                       Tapout Dance    Natalie Palomino
# 2465                        *Gentle Yoga and Meditation             Sam Kim
# 2467                         Backstage - Intro to Heels      Jazz The Poler
# 2470                                    Candle-lit Yoga           Rose Luma
# 2473                                            YES Yin        Robyn Brooke
# 2477                             POLE (Tricks & Climbs)     Foxy Instructor
# 2478                                PELOTON RESERVATION           PELOTON .
# 2484                                PELOTON RESERVATION           PELOTON .
# 2486                              Full Moon Celebration          Dallas Lyn
# 2487                                PELOTON RESERVATION           PELOTON .
#
#       rating  reviews     time  duration  \
# 0        4.9  26215.0  8:30 am        55
# 1        4.8  17389.0  8:30 am        60
# 2        4.8  19814.0  8:30 am        45
# 3        4.8   2394.0  8:30 am        60
# 4        4.9  37864.0  8:30 am        50
# 5        4.9  59396.0  8:30 am        60
# 6        4.8  41488.0  8:30 am        45
# 7        4.9  25869.0  8:30 am        50
# 8        4.8  23958.0  8:30 am        55
# 9        4.8  34598.0  8:30 am        60
# 10       4.7   7186.0  8:30 am        60
# 11       4.7   4199.0  8:30 am        50
# 12       4.9  40159.0  8:30 am        50
# 13       4.8  37118.0  8:30 am        45
# 14       4.9   3651.0  8:30 am        45
# 15       4.8  14445.0  8:30 am        65
# 16       4.8  10757.0  8:30 am        50
# 17       4.8  60835.0  8:30 am        45
# 18       4.8  31848.0  8:30 am        45
# 19       4.8   5581.0  8:30 am        60
# 20       4.8   7137.0  8:30 am        45
# 21       4.8  24358.0  8:30 am        45
# 22       4.8   5608.0  8:30 am        60
# 23       4.9   2592.0  8:30 am        60
# 24       4.8    776.0  8:30 am        55
# 25       4.9  47410.0  8:30 am        60
# 26       4.9   3639.0  8:30 am        75
# 27       4.8  40591.0  8:30 am        45
# 28       4.8  18762.0  8:30 am        45
# 29       4.8   3806.0  8:30 am        60
# ...      ...      ...      ...       ...
# 2429     4.6     32.0  7:40 pm        45
# 2430     4.6  10972.0  7:45 pm        60
# 2431     4.8  46649.0  7:45 pm        45
# 2432     4.7   9506.0  7:45 pm        75
# 2433     4.8  34598.0  7:45 pm        60
# 2434     4.7   7186.0  7:45 pm        75
# 2435     4.9  53792.0  7:45 pm        40
# 2436     4.8  26750.0  7:45 pm        65
# 2437     4.9   2480.0  7:45 pm        75
# 2438     4.8   5608.0  7:45 pm        90
# 2439     4.9  37956.0  7:50 pm        60
# 2443     4.7  21564.0  8:00 pm        60
# 2444     4.7  21564.0  8:00 pm        60
# 2450     4.9   4831.0  8:00 pm        60
# 2451     4.7   7531.0  8:00 pm        75
# 2454     4.8  11343.0  8:00 pm        90
# 2456     4.7   7431.0  8:00 pm        60
# 2457     4.5   2499.0  8:00 pm        75
# 2460     4.6    347.0  8:00 pm        30
# 2463     4.7     30.0  8:00 pm        60
# 2464     4.6     35.0  8:00 pm        60
# 2465     4.8    155.0  8:00 pm        75
# 2467     4.8     76.0  8:00 pm        60
# 2470     4.6   2900.0  8:10 pm        60
# 2473     4.9   1604.0  8:15 pm        75
# 2477     4.8   4542.0  8:30 pm        60
# 2478     4.6    347.0  8:30 pm        30
# 2484     4.6    347.0  9:00 pm        30
# 2486     4.5   2499.0  9:15 pm        90
# 2487     4.6    347.0  9:30 pm        30
#
#                                         venue           location  \
# 0                            New York Pilates               SoHo
# 1                                    SKY TING            Tribeca
# 2                            WundaBar Pilates               SoHo
# 3                                 BigToe Yoga               SoHo
# 4                            New York Pilates             Bowery
# 5                                 Physique 57               SoHo
# 6            Flywheel Sports: Stadium Cycling            Tribeca
# 7                     Exceed Physical Culture            Tribeca
# 8                            New York Pilates  Greenwich Village
# 9                                      barre3       West Village
# 10                                 ISHTA Yoga  Greenwich Village
# 11                                   FitHouse       Union Square
# 12                   NYSC Lab (featuring BFX)            Chelsea
# 13                                Cyc Fitness            Chelsea
# 14                                  Shadowbox              DUMBO
# 15                                  Yoga Vida              DUMBO
# 16                                      Brrrn           Flatiron
# 17           Flywheel Sports: Stadium Cycling           Flatiron
# 18                             Uplift Studios           Flatiron
# 19                         YO BK Williamsburg       Williamsburg
# 20    Structure Personal Fitness: Murray Hill           Kips Bay
# 21                                     Solace              NoMad
# 22                   Mark Morris Dance Center        Fort Greene
# 23                    Beyond Movement Fitness   Long Island City
# 24                            Workout Factory   Long Island City
# 25                                Physique 57            Midtown
# 26                                    Juniper   Prospect Heights
# 27           Flywheel Sports: Stadium Cycling    Upper East Side
# 28        Flywheel Sports: Precision Training    Upper East Side
# 29                           Loom Yoga Center           Bushwick
# ...                                       ...                ...
# 2429                        Dance With Me USA     Hell's Kitchen
# 2430                                YogaWorks               SoHo
# 2431                    Overthrow Boxing Club               NoHo
# 2432                       Sacred Sounds Yoga  Greenwich Village
# 2433                                   barre3       West Village
# 2434                               ISHTA Yoga  Greenwich Village
# 2435                    Switch Playground USA       Union Square
# 2436                                Yoga Vida  Greenwich Village
# 2437                              IncrediPole         Greenpoint
# 2438                 Mark Morris Dance Center        Fort Greene
# 2439                         Barry's Bootcamp            Chelsea
# 2443                    Pilates on the Square       Union Square
# 2444                    Pilates on the Square       Union Square
# 2450                           usha veda yoga         Greenpoint
# 2451                   Park Slope Yoga Center         Park Slope
# 2454                          Jewel City Yoga      Crown Heights
# 2456                                 bode nyc    Upper West Side
# 2457                                Naam Yoga    Upper West Side
# 2460                   Vigorous Fitness Clubs     Middle Village
# 2463                           Fit Body Workx           Harrison
# 2464                           Tapout Fitness         Ozone Park
# 2465                        Shiva Shanti Yoga         Rutherford
# 2467                               Studio Air          Montclair
# 2470                      Atmananda East 23rd      Gramercy Park
# 2473                               YES Studio          Ridgewood
# 2477                    Foxy Fitness and Pole            Chelsea
# 2478                   Vigorous Fitness Clubs     Middle Village
# 2484                   Vigorous Fitness Clubs     Middle Village
# 2486                                Naam Yoga    Upper West Side
# 2487                   Vigorous Fitness Clubs     Middle Village
#
#                                                    tags  price
# 0              Flexibility, Balance, Core, Abs, Pilates     25
# 1                      Flexibility, Balance, Arms, Yoga     11
# 2     Flexibility, Balance, Core, Abs, Pilates, Stre...     16
# 3                      Flexibility, Balance, Arms, Yoga      4
# 4              Flexibility, Balance, Core, Abs, Pilates     25
# 5                Flexibility, Balance, Core, Abs, Barre     12
# 6                                       Cardio, Cycling     13
# 7                                     Strength Training     12
# 8              Flexibility, Balance, Core, Abs, Pilates     25
# 9                Flexibility, Balance, Core, Abs, Barre     16
# 10                     Flexibility, Balance, Arms, Yoga      6
# 11                            Cardio, Strength Training      7
# 12                                    Strength Training      8
# 13                                      Cardio, Cycling     10
# 14                                 Cardio, Arms, Boxing     18
# 15                     Flexibility, Balance, Arms, Yoga      5
# 16                            Strength Training, Boxing      8
# 17                                      Cardio, Cycling     12
# 18                                    Strength Training     11
# 19                     Flexibility, Balance, Arms, Yoga     11
# 20                              Arms, Strength Training      7
# 21                            Cardio, Strength Training     11
# 22                  Cardio, Flexibility, Balance, Dance     10
# 23                                    Strength Training      7
# 24                                    Strength Training     11
# 25               Flexibility, Balance, Core, Abs, Barre     12
# 26           Prenatal, Flexibility, Balance, Arms, Yoga      5
# 27                                      Cardio, Cycling     12
# 28               Flexibility, Balance, Core, Abs, Barre     12
# 29                     Flexibility, Balance, Arms, Yoga      8
# ...                                                 ...    ...
# 2429                Cardio, Flexibility, Balance, Dance      6
# 2430                   Flexibility, Balance, Arms, Yoga      8
# 2431                               Cardio, Arms, Boxing      9
# 2432                                               Yoga      5
# 2433             Flexibility, Balance, Core, Abs, Barre      9
# 2434                   Flexibility, Balance, Arms, Yoga      6
# 2435                                  Strength Training      8
# 2436                   Flexibility, Balance, Arms, Yoga      6
# 2437                Cardio, Flexibility, Balance, Dance      9
# 2438                Cardio, Flexibility, Balance, Dance     10
# 2439                 Cardio, Strength Training, Running     16
# 2443           Flexibility, Balance, Core, Abs, Pilates     10
# 2444           Flexibility, Balance, Core, Abs, Pilates     10
# 2450  Relaxation, Flexibility, Balance, Arms, Medita...      4
# 2451                   Flexibility, Balance, Arms, Yoga      6
# 2454                   Flexibility, Balance, Arms, Yoga      4
# 2456                          Cardio, Strength Training      9
# 2457                   Flexibility, Balance, Arms, Yoga      6
# 2460                 Cardio, Cycling, Strength Training      4
# 2463            Cardio, Arms, Strength Training, Boxing      3
# 2464  Cardio, Flexibility, Balance, Strength Trainin...      1
# 2465                   Flexibility, Balance, Arms, Yoga      3
# 2467                Cardio, Flexibility, Balance, Dance      4
# 2470                   Flexibility, Balance, Arms, Yoga      5
# 2473                   Flexibility, Balance, Arms, Yoga      3
# 2477                Cardio, Flexibility, Balance, Dance      6
# 2478                 Cardio, Cycling, Strength Training      4
# 2484                 Cardio, Cycling, Strength Training      4
# 2486                   Flexibility, Balance, Arms, Yoga      6
# 2487                 Cardio, Cycling, Strength Training      4
#
# [1827 rows x 10 columns]

# %%
from wordcloud import WordCloud, STOPWORDS 
comment_words = ' '
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in df.location: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
#in this cell we want to group by location and analyse the effect of location on the price and the rating
location = df.groupby('location').agg('count') #grouping by location and taking the count
loc_lis = location[location['title'] > 40].index.tolist() #making a list where all of the title column is greater than 10
'''try using plotly to disaply the highest concentrated areas over a map of newyork
get the latitude and longitude of each location - can find by putting it into google -
create two new columns with latitude and longitude ''' 
df_map = location[location['title'] > 20]
df_map['latitude'] = [40.7644,40.7253,40.6959,40.7465,40.7265,40.7077,40.7401,40.7336,40.7440,40.7178,40.7174,40.7549,40.7571,40.8259,40.7287,40.7446,40.6711,40.7233,40.7163,40.7359,40.7736,40.7870,40.7347,40.7081]
df_map['longitude'] = [-73.9235,-73.9903,-73.9956,-74.0014,-73.9815,-74.0083,-73.9903,-74.0027,-74.0324,-74.0431,-73.8743,-73.9840,-73.9719,-74.2090,-73.9926,-73.9874,-73.9814,-74.0030,-74.0086,-73.9911,-73.9566,-73.9754,-74.0048,-73.9571]
df_map
# Out:
# /Users/georgealster/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/georgealster/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                     title  instructor  rating  reviews  time  duration  venue  \
# location
# Astoria                36          36      36       36    36        36     36
# Bowery                 27          27      27       27    27        27     27
# Brooklyn Heights       32          32      32       32    32        32     32
# Chelsea                56          56      56       56    56        56     56
# East Village           39          39      39       39    39        39     39
# Financial District     27          27      27       27    27        27     27
# Flatiron               93          93      93       93    93        93     93
# Greenwich Village      58          58      58       58    58        58     58
# Hoboken                33          33      33       33    33        33     33
# Jersey City            40          40      40       40    40        40     40
# Middle Village         28          28      28       28    28        28     28
# Midtown                41          41      41       41    41        41     41
# Midtown East           45          45      45       45    45        45     45
# Montclair              22          22      22       22    22        22     22
# NoHo                   41          41      41       41    41        41     41
# NoMad                  60          60      60       60    60        60     60
# Park Slope             36          36      36       36    36        36     36
# SoHo                   62          62      62       62    62        62     62
# Tribeca                73          73      73       73    73        73     73
# Union Square           58          58      58       58    58        58     58
# Upper East Side       151         151     151      151   151       151    151
# Upper West Side       139         139     139      139   139       139    139
# West Village           22          22      22       22    22        22     22
# Williamsburg           65          65      65       65    65        65     65
#
#                     tags  price  latitude  longitude
# location
# Astoria               36     36   40.7644   -73.9235
# Bowery                27     27   40.7253   -73.9903
# Brooklyn Heights      32     32   40.6959   -73.9956
# Chelsea               56     56   40.7465   -74.0014
# East Village          39     39   40.7265   -73.9815
# Financial District    27     27   40.7077   -74.0083
# Flatiron              93     93   40.7401   -73.9903
# Greenwich Village     58     58   40.7336   -74.0027
# Hoboken               33     33   40.7440   -74.0324
# Jersey City           40     40   40.7178   -74.0431
# Middle Village        28     28   40.7174   -73.8743
# Midtown               41     41   40.7549   -73.9840
# Midtown East          45     45   40.7571   -73.9719
# Montclair             22     22   40.8259   -74.2090
# NoHo                  41     41   40.7287   -73.9926
# NoMad                 60     60   40.7446   -73.9874
# Park Slope            36     36   40.6711   -73.9814
# SoHo                  62     62   40.7233   -74.0030
# Tribeca               73     73   40.7163   -74.0086
# Union Square          58     58   40.7359   -73.9911
# Upper East Side      151    151   40.7736   -73.9566
# Upper West Side      139    139   40.7870   -73.9754
# West Village          22     22   40.7347   -74.0048
# Williamsburg          65     65   40.7081   -73.9571

# %%
folium_map = folium.Map(location=[40.738, -73.98],
                        zoom_start=13,
                        tiles="CartoDB dark_matter")

folium.CircleMarker(location=[40.738, -73.98],fill=True).add_to(folium_map)
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def plot_gym_counts(df_map):
    # generate a new map
    folium_map = folium.Map(location=[40.738, -73.98],
                            zoom_start=13,
                            tiles="CartoDB dark_matter",
                            width='50%')

    # for each row in the data, add a cicle marker
    for index, row in df_map.iterrows():
        # calculate net departures
#         net_departures = (row["Departure Count"]-row["Arrival Count"])
        
        # generate the popup message that is shown on click.
        popup_text = "{}<br> total gyms"
        popup_text = popup_text.format(row["title"])
        
        # radius of circles
        radius = row["title"]
        
        # choose the color of the marker
        if row["title"]>40:
            # color="#FFCE00" # orange
            # color="#007849" # green
            color="#E37222" # tangerine
        else:
            # color="#0375B4" # blue
            # color="#FFCE00" # yellow            
            color="#0A8A9F" # teal
        
        # add marker to the map
        folium.CircleMarker(location=(row["latitude"],
                                      row["longitude"]),
                            radius=radius,
                            color=color,
                            popup = popup_text,
                            fill=True).add_to(folium_map)
        html_string = m._repr_html_()
    return folium_map

# %%
plot_gym_counts(df_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
filt_df = df[df['location'].isin(loc_lis)] #filter the dataframe for locations with more than 10 gyms 
filt_df

# %%
filt_df.groupby('location') #here we want to groupby location and venue

# %%
loc_price = filt_df.groupby('location').mean()['price'] #mean price per location 
loc_reviews = filt_df.groupby('location').mean()['reviews'] #reviews against location
loc_rating = filt_df.groupby('location').mean()['rating'] #rating against location
loc_reviews
# Out:
# location
# Chelsea              21666.464286
# Flatiron             24975.462366
# Greenwich Village    16047.051724
# Midtown              26275.975610
# Midtown East         11333.177778
# NoHo                 34190.780488
# NoMad                24316.600000
# SoHo                 23494.258065
# Tribeca              13477.876712
# Union Square         19198.862069
# Upper East Side      15159.629139
# Upper West Side      13076.345324
# Williamsburg         11852.107692
# Name: reviews, dtype: float64

# %%
type(loc_price)
# Out:
# pandas.core.series.Series

# %%
loc_reviews.head(4)
# Out:
# location
# Chelsea              21666.464286
# Flatiron             24975.462366
# Greenwich Village    16047.051724
# Midtown              26275.975610
# Name: reviews, dtype: float64

# %%
fig = plt.figure() # Create matplotlib figure
fig.set_size_inches(18.5, 10.5)

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twiny() # Create another axes that shares the same y-axis as ay.

width = 0.3

p1 = loc_price.sort_values(ascending=True).plot(kind='barh', color='r', ax=ax, width=width, position =1, legend = True,label = 'Price')
p2 = loc_reviews.plot(kind='barh', color='blue', ax=ax2, width=width, position=0,legend = True,label = 'Reviews')


ax.set_xlabel('Price')
ax2.set_xlabel('Reviews')
plt.ylabel('Location')
plt.title('Location specific pricing and popularity', fontsize=18)
ax2.legend(loc = 'lower right')
ax.legend(loc = 'lower right', borderaxespad = 2)
plt.show()

# %%
df
# Out:
#                                                   title          instructor  \
# 0                        Pilates Reformer: Abs Arms Ass          Meg Broome
# 1                                         SKY TING Yoga        Grace Dubery
# 2                                      WundaBar Workout     Marta Picaporte
# 3                                           BigToe Flow    Patrick Rafferty
# 4                             Pilates Reformer: Burnout        Lisa Jantzie
# 5                                          Signature II      Veronika Cohen
# 6                                   Flywheel: Method 45        Cedric Green
# 7                                   EXCEED: The Workout        Jed Cabreira
# 8                    Pilates Reformer: Sculpt + Restore         Heran Haile
# 9                                                barre3        Jenna Muller
# 10                                        ISHTA Vinyasa      Mikaela Soldan
# 11                                                 HIIT       Tatiana Lampa
# 12                                          B3 x Tomíçs       Tomas Rodgers
# 13                                                Cyc45     Michael Clement
# 14                                 SHADOWBOX - STANDARD             Brendan
# 15                                          Heated Flow           Amy Wolfe
# 16                                                  HIT       Scott Freeman
# 17                                  Flywheel: Method 45       Steven Little
# 18                                       UPLIFT EXPRESS         Meg Hopkins
# 19                               Bikram Yoga 60 - Music      Sara Corenzwit
# 20    Strength Training: Lower Body (formerly Glutes...      Lariscy Walker
# 21                                            Body (AM)      Danielle Barry
# 22                                   Adult: Gaga.People       Gaga *Faculty
# 23                                                 LIFT            Jenni M.
# 24                                             BOOTCAMP     Alex R Redelico
# 25                                          Signature I         Sally Glaze
# 26                                             Prenatal        Sonia Reiter
# 27                                  Flywheel: Method 45      Nowani Rattray
# 28                                   FlyBarre: Power 45     Michelle Rubich
# 29                                             All Flow        Natalie Girs
# ...                                                 ...                 ...
# 2429        Ladies Technique and Styling in Cha Cha Cha               Mandy
# 2430                               Restorative w/ Music     Alystyre Julian
# 2431                       Overthrow Underground Boxing           Julian D.
# 2432                              Candlelit Chakra Flow        Lauren Logan
# 2433                                             barre3       Amanda Fruitt
# 2434                              Candlelit Restorative     Donald Johnston
# 2435                          Switch40 - Cardio Circuit        Brian Miller
# 2436                                      Flow + Let Go       Allie Gardner
# 2437          Russian Exotic *PREREQUISITE BEGINNER II*  Casey Leigh Jordan
# 2438                     Adult: Open Level West African     Ismael *Kouyate
# 2439                            Total Body (60 Minutes)     Matthew Griffin
# 2443                             Pilates Machine Class.  Natalie Labellarte
# 2444                              Pilates Machine Class   Cassie Washington
# 2450      Restorative & Yoga Nidra Meditation (Level 1)        Christie Roe
# 2451                            Basic Vinyasa + Restore         Dana Greene
# 2454                                     Flow & Restore      Emily Nachazel
# 2456                                           Hot HIIT       Monique Crous
# 2457                                  Naam Aromatherapy          Dallas Lyn
# 2460                                PELOTON RESERVATION           PELOTON .
# 2463                                  Cardio Kickboxing        Diego Araujo
# 2464                                       Tapout Dance    Natalie Palomino
# 2465                        *Gentle Yoga and Meditation             Sam Kim
# 2467                         Backstage - Intro to Heels      Jazz The Poler
# 2470                                    Candle-lit Yoga           Rose Luma
# 2473                                            YES Yin        Robyn Brooke
# 2477                             POLE (Tricks & Climbs)     Foxy Instructor
# 2478                                PELOTON RESERVATION           PELOTON .
# 2484                                PELOTON RESERVATION           PELOTON .
# 2486                              Full Moon Celebration          Dallas Lyn
# 2487                                PELOTON RESERVATION           PELOTON .
#
#       rating  reviews     time  duration  \
# 0        4.9  26215.0  8:30 am        55
# 1        4.8  17389.0  8:30 am        60
# 2        4.8  19814.0  8:30 am        45
# 3        4.8   2394.0  8:30 am        60
# 4        4.9  37864.0  8:30 am        50
# 5        4.9  59396.0  8:30 am        60
# 6        4.8  41488.0  8:30 am        45
# 7        4.9  25869.0  8:30 am        50
# 8        4.8  23958.0  8:30 am        55
# 9        4.8  34598.0  8:30 am        60
# 10       4.7   7186.0  8:30 am        60
# 11       4.7   4199.0  8:30 am        50
# 12       4.9  40159.0  8:30 am        50
# 13       4.8  37118.0  8:30 am        45
# 14       4.9   3651.0  8:30 am        45
# 15       4.8  14445.0  8:30 am        65
# 16       4.8  10757.0  8:30 am        50
# 17       4.8  60835.0  8:30 am        45
# 18       4.8  31848.0  8:30 am        45
# 19       4.8   5581.0  8:30 am        60
# 20       4.8   7137.0  8:30 am        45
# 21       4.8  24358.0  8:30 am        45
# 22       4.8   5608.0  8:30 am        60
# 23       4.9   2592.0  8:30 am        60
# 24       4.8    776.0  8:30 am        55
# 25       4.9  47410.0  8:30 am        60
# 26       4.9   3639.0  8:30 am        75
# 27       4.8  40591.0  8:30 am        45
# 28       4.8  18762.0  8:30 am        45
# 29       4.8   3806.0  8:30 am        60
# ...      ...      ...      ...       ...
# 2429     4.6     32.0  7:40 pm        45
# 2430     4.6  10972.0  7:45 pm        60
# 2431     4.8  46649.0  7:45 pm        45
# 2432     4.7   9506.0  7:45 pm        75
# 2433     4.8  34598.0  7:45 pm        60
# 2434     4.7   7186.0  7:45 pm        75
# 2435     4.9  53792.0  7:45 pm        40
# 2436     4.8  26750.0  7:45 pm        65
# 2437     4.9   2480.0  7:45 pm        75
# 2438     4.8   5608.0  7:45 pm        90
# 2439     4.9  37956.0  7:50 pm        60
# 2443     4.7  21564.0  8:00 pm        60
# 2444     4.7  21564.0  8:00 pm        60
# 2450     4.9   4831.0  8:00 pm        60
# 2451     4.7   7531.0  8:00 pm        75
# 2454     4.8  11343.0  8:00 pm        90
# 2456     4.7   7431.0  8:00 pm        60
# 2457     4.5   2499.0  8:00 pm        75
# 2460     4.6    347.0  8:00 pm        30
# 2463     4.7     30.0  8:00 pm        60
# 2464     4.6     35.0  8:00 pm        60
# 2465     4.8    155.0  8:00 pm        75
# 2467     4.8     76.0  8:00 pm        60
# 2470     4.6   2900.0  8:10 pm        60
# 2473     4.9   1604.0  8:15 pm        75
# 2477     4.8   4542.0  8:30 pm        60
# 2478     4.6    347.0  8:30 pm        30
# 2484     4.6    347.0  9:00 pm        30
# 2486     4.5   2499.0  9:15 pm        90
# 2487     4.6    347.0  9:30 pm        30
#
#                                         venue           location  \
# 0                            New York Pilates               SoHo
# 1                                    SKY TING            Tribeca
# 2                            WundaBar Pilates               SoHo
# 3                                 BigToe Yoga               SoHo
# 4                            New York Pilates             Bowery
# 5                                 Physique 57               SoHo
# 6            Flywheel Sports: Stadium Cycling            Tribeca
# 7                     Exceed Physical Culture            Tribeca
# 8                            New York Pilates  Greenwich Village
# 9                                      barre3       West Village
# 10                                 ISHTA Yoga  Greenwich Village
# 11                                   FitHouse       Union Square
# 12                   NYSC Lab (featuring BFX)            Chelsea
# 13                                Cyc Fitness            Chelsea
# 14                                  Shadowbox              DUMBO
# 15                                  Yoga Vida              DUMBO
# 16                                      Brrrn           Flatiron
# 17           Flywheel Sports: Stadium Cycling           Flatiron
# 18                             Uplift Studios           Flatiron
# 19                         YO BK Williamsburg       Williamsburg
# 20    Structure Personal Fitness: Murray Hill           Kips Bay
# 21                                     Solace              NoMad
# 22                   Mark Morris Dance Center        Fort Greene
# 23                    Beyond Movement Fitness   Long Island City
# 24                            Workout Factory   Long Island City
# 25                                Physique 57            Midtown
# 26                                    Juniper   Prospect Heights
# 27           Flywheel Sports: Stadium Cycling    Upper East Side
# 28        Flywheel Sports: Precision Training    Upper East Side
# 29                           Loom Yoga Center           Bushwick
# ...                                       ...                ...
# 2429                        Dance With Me USA     Hell's Kitchen
# 2430                                YogaWorks               SoHo
# 2431                    Overthrow Boxing Club               NoHo
# 2432                       Sacred Sounds Yoga  Greenwich Village
# 2433                                   barre3       West Village
# 2434                               ISHTA Yoga  Greenwich Village
# 2435                    Switch Playground USA       Union Square
# 2436                                Yoga Vida  Greenwich Village
# 2437                              IncrediPole         Greenpoint
# 2438                 Mark Morris Dance Center        Fort Greene
# 2439                         Barry's Bootcamp            Chelsea
# 2443                    Pilates on the Square       Union Square
# 2444                    Pilates on the Square       Union Square
# 2450                           usha veda yoga         Greenpoint
# 2451                   Park Slope Yoga Center         Park Slope
# 2454                          Jewel City Yoga      Crown Heights
# 2456                                 bode nyc    Upper West Side
# 2457                                Naam Yoga    Upper West Side
# 2460                   Vigorous Fitness Clubs     Middle Village
# 2463                           Fit Body Workx           Harrison
# 2464                           Tapout Fitness         Ozone Park
# 2465                        Shiva Shanti Yoga         Rutherford
# 2467                               Studio Air          Montclair
# 2470                      Atmananda East 23rd      Gramercy Park
# 2473                               YES Studio          Ridgewood
# 2477                    Foxy Fitness and Pole            Chelsea
# 2478                   Vigorous Fitness Clubs     Middle Village
# 2484                   Vigorous Fitness Clubs     Middle Village
# 2486                                Naam Yoga    Upper West Side
# 2487                   Vigorous Fitness Clubs     Middle Village
#
#                                                    tags  price
# 0              Flexibility, Balance, Core, Abs, Pilates     25
# 1                      Flexibility, Balance, Arms, Yoga     11
# 2     Flexibility, Balance, Core, Abs, Pilates, Stre...     16
# 3                      Flexibility, Balance, Arms, Yoga      4
# 4              Flexibility, Balance, Core, Abs, Pilates     25
# 5                Flexibility, Balance, Core, Abs, Barre     12
# 6                                       Cardio, Cycling     13
# 7                                     Strength Training     12
# 8              Flexibility, Balance, Core, Abs, Pilates     25
# 9                Flexibility, Balance, Core, Abs, Barre     16
# 10                     Flexibility, Balance, Arms, Yoga      6
# 11                            Cardio, Strength Training      7
# 12                                    Strength Training      8
# 13                                      Cardio, Cycling     10
# 14                                 Cardio, Arms, Boxing     18
# 15                     Flexibility, Balance, Arms, Yoga      5
# 16                            Strength Training, Boxing      8
# 17                                      Cardio, Cycling     12
# 18                                    Strength Training     11
# 19                     Flexibility, Balance, Arms, Yoga     11
# 20                              Arms, Strength Training      7
# 21                            Cardio, Strength Training     11
# 22                  Cardio, Flexibility, Balance, Dance     10
# 23                                    Strength Training      7
# 24                                    Strength Training     11
# 25               Flexibility, Balance, Core, Abs, Barre     12
# 26           Prenatal, Flexibility, Balance, Arms, Yoga      5
# 27                                      Cardio, Cycling     12
# 28               Flexibility, Balance, Core, Abs, Barre     12
# 29                     Flexibility, Balance, Arms, Yoga      8
# ...                                                 ...    ...
# 2429                Cardio, Flexibility, Balance, Dance      6
# 2430                   Flexibility, Balance, Arms, Yoga      8
# 2431                               Cardio, Arms, Boxing      9
# 2432                                               Yoga      5
# 2433             Flexibility, Balance, Core, Abs, Barre      9
# 2434                   Flexibility, Balance, Arms, Yoga      6
# 2435                                  Strength Training      8
# 2436                   Flexibility, Balance, Arms, Yoga      6
# 2437                Cardio, Flexibility, Balance, Dance      9
# 2438                Cardio, Flexibility, Balance, Dance     10
# 2439                 Cardio, Strength Training, Running     16
# 2443           Flexibility, Balance, Core, Abs, Pilates     10
# 2444           Flexibility, Balance, Core, Abs, Pilates     10
# 2450  Relaxation, Flexibility, Balance, Arms, Medita...      4
# 2451                   Flexibility, Balance, Arms, Yoga      6
# 2454                   Flexibility, Balance, Arms, Yoga      4
# 2456                          Cardio, Strength Training      9
# 2457                   Flexibility, Balance, Arms, Yoga      6
# 2460                 Cardio, Cycling, Strength Training      4
# 2463            Cardio, Arms, Strength Training, Boxing      3
# 2464  Cardio, Flexibility, Balance, Strength Trainin...      1
# 2465                   Flexibility, Balance, Arms, Yoga      3
# 2467                Cardio, Flexibility, Balance, Dance      4
# 2470                   Flexibility, Balance, Arms, Yoga      5
# 2473                   Flexibility, Balance, Arms, Yoga      3
# 2477                Cardio, Flexibility, Balance, Dance      6
# 2478                 Cardio, Cycling, Strength Training      4
# 2484                 Cardio, Cycling, Strength Training      4
# 2486                   Flexibility, Balance, Arms, Yoga      6
# 2487                 Cardio, Cycling, Strength Training      4
#
# [1827 rows x 10 columns]

# %%
'''finding the most popular gym within each main neighborhood of nyc'''


loc_ven = filt_df.groupby(['location','venue']).agg(['mean'])['reviews']
loc_ven_max = loc_ven.groupby('location').max()
loc_ven
loc_ven_max
final = loc_ven[loc_ven['mean'].isin(loc_ven_max['mean'])]
final.round()
# Out:
#                                                        mean
# location          venue
# Chelsea           Peloton Cycling Studio            73326.0
# Flatiron          Flywheel Sports: Stadium Cycling  60835.0
# Greenwich Village Liftonic                          27331.0
# Midtown           Physique 57                       47410.0
# Midtown East      EverybodyFights                   31891.0
# NoHo              Mile High Run Club                64383.0
# NoMad             Mile High Run Club                73417.0
# SoHo              Physique 57                       59396.0
# Tribeca           Flywheel Sports: Stadium Cycling  41488.0
# Union Square      Switch Playground USA             53792.0
# Upper East Side   Y7 Studio                         48005.0
# Upper West Side   Physique 57                       50230.0
# Williamsburg      Flywheel Sports: Stadium Cycling  41823.0

# %%
def tidy_split(df, column, sep=',', keep=False):
    """
    Split the values of a column and expand so the new DataFrame has one split
    value per row. Filters rows where the column is missing.

    Params
    ------
    df : pandas.DataFrame
        dataframe with the column to split and expand
    column : str
        the column to split and expand
    sep : str
        the string used to split the column's values
    keep : bool
        whether to retain the presplit value as it's own row

    Returns
    -------
    pandas.DataFrame
        Returns a dataframe with the same columns as `df`.
    """
    indexes = list()
    new_values = list()
    df = df.dropna(subset=[column])
    for i, presplit in enumerate(df[column].astype(str)):
        values = presplit.split(sep)
        if keep and len(values) > 1:
            indexes.append(i)
            new_values.append(presplit)
        for value in values:
            indexes.append(i)
            new_values.append(value)
    new_df = df.iloc[indexes, :].copy()
    new_df[column] = new_values
    return new_df
tag_split_df = tidy_split(df,'tags')
tag_split_df = tag_split_df.replace('Martial Arts','Martial_Arts')
tag_split_df = tag_split_df.replace(' ','')
tag_split_df
# tag_split_df.groupby('tags').count()
# Out:
#                                title        instructor  rating  reviews  \
# 0     Pilates Reformer: Abs Arms Ass        Meg Broome     4.9  26215.0
# 0     Pilates Reformer: Abs Arms Ass        Meg Broome     4.9  26215.0
# 0     Pilates Reformer: Abs Arms Ass        Meg Broome     4.9  26215.0
# 0     Pilates Reformer: Abs Arms Ass        Meg Broome     4.9  26215.0
# 0     Pilates Reformer: Abs Arms Ass        Meg Broome     4.9  26215.0
# 1                      SKY TING Yoga      Grace Dubery     4.8  17389.0
# 1                      SKY TING Yoga      Grace Dubery     4.8  17389.0
# 1                      SKY TING Yoga      Grace Dubery     4.8  17389.0
# 1                      SKY TING Yoga      Grace Dubery     4.8  17389.0
# 2                   WundaBar Workout   Marta Picaporte     4.8  19814.0
# 2                   WundaBar Workout   Marta Picaporte     4.8  19814.0
# 2                   WundaBar Workout   Marta Picaporte     4.8  19814.0
# 2                   WundaBar Workout   Marta Picaporte     4.8  19814.0
# 2                   WundaBar Workout   Marta Picaporte     4.8  19814.0
# 2                   WundaBar Workout   Marta Picaporte     4.8  19814.0
# 3                        BigToe Flow  Patrick Rafferty     4.8   2394.0
# 3                        BigToe Flow  Patrick Rafferty     4.8   2394.0
# 3                        BigToe Flow  Patrick Rafferty     4.8   2394.0
# 3                        BigToe Flow  Patrick Rafferty     4.8   2394.0
# 4          Pilates Reformer: Burnout      Lisa Jantzie     4.9  37864.0
# 4          Pilates Reformer: Burnout      Lisa Jantzie     4.9  37864.0
# 4          Pilates Reformer: Burnout      Lisa Jantzie     4.9  37864.0
# 4          Pilates Reformer: Burnout      Lisa Jantzie     4.9  37864.0
# 4          Pilates Reformer: Burnout      Lisa Jantzie     4.9  37864.0
# 5                       Signature II    Veronika Cohen     4.9  59396.0
# 5                       Signature II    Veronika Cohen     4.9  59396.0
# 5                       Signature II    Veronika Cohen     4.9  59396.0
# 5                       Signature II    Veronika Cohen     4.9  59396.0
# 5                       Signature II    Veronika Cohen     4.9  59396.0
# 6                Flywheel: Method 45      Cedric Green     4.8  41488.0
# ...                              ...               ...     ...      ...
# 2465     *Gentle Yoga and Meditation           Sam Kim     4.8    155.0
# 2467      Backstage - Intro to Heels    Jazz The Poler     4.8     76.0
# 2467      Backstage - Intro to Heels    Jazz The Poler     4.8     76.0
# 2467      Backstage - Intro to Heels    Jazz The Poler     4.8     76.0
# 2467      Backstage - Intro to Heels    Jazz The Poler     4.8     76.0
# 2470                 Candle-lit Yoga         Rose Luma     4.6   2900.0
# 2470                 Candle-lit Yoga         Rose Luma     4.6   2900.0
# 2470                 Candle-lit Yoga         Rose Luma     4.6   2900.0
# 2470                 Candle-lit Yoga         Rose Luma     4.6   2900.0
# 2473                         YES Yin      Robyn Brooke     4.9   1604.0
# 2473                         YES Yin      Robyn Brooke     4.9   1604.0
# 2473                         YES Yin      Robyn Brooke     4.9   1604.0
# 2473                         YES Yin      Robyn Brooke     4.9   1604.0
# 2477          POLE (Tricks & Climbs)   Foxy Instructor     4.8   4542.0
# 2477          POLE (Tricks & Climbs)   Foxy Instructor     4.8   4542.0
# 2477          POLE (Tricks & Climbs)   Foxy Instructor     4.8   4542.0
# 2477          POLE (Tricks & Climbs)   Foxy Instructor     4.8   4542.0
# 2478             PELOTON RESERVATION         PELOTON .     4.6    347.0
# 2478             PELOTON RESERVATION         PELOTON .     4.6    347.0
# 2478             PELOTON RESERVATION         PELOTON .     4.6    347.0
# 2484             PELOTON RESERVATION         PELOTON .     4.6    347.0
# 2484             PELOTON RESERVATION         PELOTON .     4.6    347.0
# 2484             PELOTON RESERVATION         PELOTON .     4.6    347.0
# 2486           Full Moon Celebration        Dallas Lyn     4.5   2499.0
# 2486           Full Moon Celebration        Dallas Lyn     4.5   2499.0
# 2486           Full Moon Celebration        Dallas Lyn     4.5   2499.0
# 2486           Full Moon Celebration        Dallas Lyn     4.5   2499.0
# 2487             PELOTON RESERVATION         PELOTON .     4.6    347.0
# 2487             PELOTON RESERVATION         PELOTON .     4.6    347.0
# 2487             PELOTON RESERVATION         PELOTON .     4.6    347.0
#
#          time  duration                             venue         location  \
# 0     8:30 am        55                  New York Pilates             SoHo
# 0     8:30 am        55                  New York Pilates             SoHo
# 0     8:30 am        55                  New York Pilates             SoHo
# 0     8:30 am        55                  New York Pilates             SoHo
# 0     8:30 am        55                  New York Pilates             SoHo
# 1     8:30 am        60                          SKY TING          Tribeca
# 1     8:30 am        60                          SKY TING          Tribeca
# 1     8:30 am        60                          SKY TING          Tribeca
# 1     8:30 am        60                          SKY TING          Tribeca
# 2     8:30 am        45                  WundaBar Pilates             SoHo
# 2     8:30 am        45                  WundaBar Pilates             SoHo
# 2     8:30 am        45                  WundaBar Pilates             SoHo
# 2     8:30 am        45                  WundaBar Pilates             SoHo
# 2     8:30 am        45                  WundaBar Pilates             SoHo
# 2     8:30 am        45                  WundaBar Pilates             SoHo
# 3     8:30 am        60                       BigToe Yoga             SoHo
# 3     8:30 am        60                       BigToe Yoga             SoHo
# 3     8:30 am        60                       BigToe Yoga             SoHo
# 3     8:30 am        60                       BigToe Yoga             SoHo
# 4     8:30 am        50                  New York Pilates           Bowery
# 4     8:30 am        50                  New York Pilates           Bowery
# 4     8:30 am        50                  New York Pilates           Bowery
# 4     8:30 am        50                  New York Pilates           Bowery
# 4     8:30 am        50                  New York Pilates           Bowery
# 5     8:30 am        60                       Physique 57             SoHo
# 5     8:30 am        60                       Physique 57             SoHo
# 5     8:30 am        60                       Physique 57             SoHo
# 5     8:30 am        60                       Physique 57             SoHo
# 5     8:30 am        60                       Physique 57             SoHo
# 6     8:30 am        45  Flywheel Sports: Stadium Cycling          Tribeca
# ...       ...       ...                               ...              ...
# 2465  8:00 pm        75                 Shiva Shanti Yoga       Rutherford
# 2467  8:00 pm        60                        Studio Air        Montclair
# 2467  8:00 pm        60                        Studio Air        Montclair
# 2467  8:00 pm        60                        Studio Air        Montclair
# 2467  8:00 pm        60                        Studio Air        Montclair
# 2470  8:10 pm        60               Atmananda East 23rd    Gramercy Park
# 2470  8:10 pm        60               Atmananda East 23rd    Gramercy Park
# 2470  8:10 pm        60               Atmananda East 23rd    Gramercy Park
# 2470  8:10 pm        60               Atmananda East 23rd    Gramercy Park
# 2473  8:15 pm        75                        YES Studio        Ridgewood
# 2473  8:15 pm        75                        YES Studio        Ridgewood
# 2473  8:15 pm        75                        YES Studio        Ridgewood
# 2473  8:15 pm        75                        YES Studio        Ridgewood
# 2477  8:30 pm        60             Foxy Fitness and Pole          Chelsea
# 2477  8:30 pm        60             Foxy Fitness and Pole          Chelsea
# 2477  8:30 pm        60             Foxy Fitness and Pole          Chelsea
# 2477  8:30 pm        60             Foxy Fitness and Pole          Chelsea
# 2478  8:30 pm        30            Vigorous Fitness Clubs   Middle Village
# 2478  8:30 pm        30            Vigorous Fitness Clubs   Middle Village
# 2478  8:30 pm        30            Vigorous Fitness Clubs   Middle Village
# 2484  9:00 pm        30            Vigorous Fitness Clubs   Middle Village
# 2484  9:00 pm        30            Vigorous Fitness Clubs   Middle Village
# 2484  9:00 pm        30            Vigorous Fitness Clubs   Middle Village
# 2486  9:15 pm        90                         Naam Yoga  Upper West Side
# 2486  9:15 pm        90                         Naam Yoga  Upper West Side
# 2486  9:15 pm        90                         Naam Yoga  Upper West Side
# 2486  9:15 pm        90                         Naam Yoga  Upper West Side
# 2487  9:30 pm        30            Vigorous Fitness Clubs   Middle Village
# 2487  9:30 pm        30            Vigorous Fitness Clubs   Middle Village
# 2487  9:30 pm        30            Vigorous Fitness Clubs   Middle Village
#
#                     tags  price
# 0            Flexibility     25
# 0                Balance     25
# 0                   Core     25
# 0                    Abs     25
# 0                Pilates     25
# 1            Flexibility     11
# 1                Balance     11
# 1                   Arms     11
# 1                   Yoga     11
# 2            Flexibility     16
# 2                Balance     16
# 2                   Core     16
# 2                    Abs     16
# 2                Pilates     16
# 2      Strength Training     16
# 3            Flexibility      4
# 3                Balance      4
# 3                   Arms      4
# 3                   Yoga      4
# 4            Flexibility     25
# 4                Balance     25
# 4                   Core     25
# 4                    Abs     25
# 4                Pilates     25
# 5            Flexibility     12
# 5                Balance     12
# 5                   Core     12
# 5                    Abs     12
# 5                  Barre     12
# 6                 Cardio     13
# ...                  ...    ...
# 2465                Yoga      3
# 2467              Cardio      4
# 2467         Flexibility      4
# 2467             Balance      4
# 2467               Dance      4
# 2470         Flexibility      5
# 2470             Balance      5
# 2470                Arms      5
# 2470                Yoga      5
# 2473         Flexibility      3
# 2473             Balance      3
# 2473                Arms      3
# 2473                Yoga      3
# 2477              Cardio      6
# 2477         Flexibility      6
# 2477             Balance      6
# 2477               Dance      6
# 2478              Cardio      4
# 2478             Cycling      4
# 2478   Strength Training      4
# 2484              Cardio      4
# 2484             Cycling      4
# 2484   Strength Training      4
# 2486         Flexibility      6
# 2486             Balance      6
# 2486                Arms      6
# 2486                Yoga      6
# 2487              Cardio      4
# 2487             Cycling      4
# 2487   Strength Training      4
#
# [6445 rows x 10 columns]

# %%
genre_list = [" Cycling"," Yoga"," Pilates"," Boxing"," Dance"," Martial_Arts"]
genres = tag_split_df[(tag_split_df['tags'].isin(genre_list))]
genre_reviews = genres.groupby('tags').mean()['reviews'] #check to see how different types of class vary with no reviews 
genre_price = genres.groupby('tags').mean()['price'] #check to see how different types of class vary with price
genre_durat = genres.groupby('tags').mean()['duration'] #check to see how different types of class vary with time
genres
# Out:
#                                               title           instructor  \
# 0                    Pilates Reformer: Abs Arms Ass           Meg Broome
# 1                                     SKY TING Yoga         Grace Dubery
# 2                                  WundaBar Workout      Marta Picaporte
# 3                                       BigToe Flow     Patrick Rafferty
# 4                         Pilates Reformer: Burnout         Lisa Jantzie
# 6                               Flywheel: Method 45         Cedric Green
# 8                Pilates Reformer: Sculpt + Restore          Heran Haile
# 10                                    ISHTA Vinyasa       Mikaela Soldan
# 13                                            Cyc45      Michael Clement
# 14                             SHADOWBOX - STANDARD              Brendan
# 15                                      Heated Flow            Amy Wolfe
# 16                                              HIT        Scott Freeman
# 17                              Flywheel: Method 45        Steven Little
# 19                           Bikram Yoga 60 - Music       Sara Corenzwit
# 22                               Adult: Gaga.People        Gaga *Faculty
# 26                                         Prenatal         Sonia Reiter
# 27                              Flywheel: Method 45       Nowani Rattray
# 29                                         All Flow         Natalie Girs
# 31                      Flywheel: Method 45 - #FBF!     Garret Caillouet
# 35                              Flywheel: Method 45        Bryan Jarrett
# 38                                      Gyrokinesis            Ezhra Goh
# 38                                      Gyrokinesis            Ezhra Goh
# 39                                 Five Pillars 360        Lauren Harris
# 40                                         REFORMER          Sam Mitrani
# 43                              PELOTON RESERVATION            PELOTON .
# 44           IM=X Pilates Basic Xercizer - BEGINNER       BettyAnn Niece
# 45                     IM=X Inter/Advanced Xercizer  Dr. Michael Magwood
# 47                                      Rev Rhythms     Kathleen Tobacco
# 52                                  Kickboxing Plus        Deena Warshaw
# 53                                     BARRE SCULPT      JonnaLyn Panico
# ...                                             ...                  ...
# 2411                                    YOGA: Hatha           Nyota Nayo
# 2412                                          Zumba              Crystal
# 2418                                       Yin Yoga       Christi Himiob
# 2425                                 Community Yoga      Juluka Teachers
# 2428        STRIPPER STRENGTH: Splits S-t-r-e-t-c-h                 KZ D
# 2429    Ladies Technique and Styling in Cha Cha Cha                Mandy
# 2430                           Restorative w/ Music      Alystyre Julian
# 2431                   Overthrow Underground Boxing            Julian D.
# 2434                          Candlelit Restorative      Donald Johnston
# 2436                                  Flow + Let Go        Allie Gardner
# 2437      Russian Exotic *PREREQUISITE BEGINNER II*   Casey Leigh Jordan
# 2438                 Adult: Open Level West African      Ismael *Kouyate
# 2443                         Pilates Machine Class.   Natalie Labellarte
# 2444                          Pilates Machine Class    Cassie Washington
# 2450  Restorative & Yoga Nidra Meditation (Level 1)         Christie Roe
# 2451                        Basic Vinyasa + Restore          Dana Greene
# 2454                                 Flow & Restore       Emily Nachazel
# 2457                              Naam Aromatherapy           Dallas Lyn
# 2460                            PELOTON RESERVATION            PELOTON .
# 2463                              Cardio Kickboxing         Diego Araujo
# 2464                                   Tapout Dance     Natalie Palomino
# 2465                    *Gentle Yoga and Meditation              Sam Kim
# 2467                     Backstage - Intro to Heels       Jazz The Poler
# 2470                                Candle-lit Yoga            Rose Luma
# 2473                                        YES Yin         Robyn Brooke
# 2477                         POLE (Tricks & Climbs)      Foxy Instructor
# 2478                            PELOTON RESERVATION            PELOTON .
# 2484                            PELOTON RESERVATION            PELOTON .
# 2486                          Full Moon Celebration           Dallas Lyn
# 2487                            PELOTON RESERVATION            PELOTON .
#
#       rating  reviews     time  duration                             venue  \
# 0        4.9  26215.0  8:30 am        55                  New York Pilates
# 1        4.8  17389.0  8:30 am        60                          SKY TING
# 2        4.8  19814.0  8:30 am        45                  WundaBar Pilates
# 3        4.8   2394.0  8:30 am        60                       BigToe Yoga
# 4        4.9  37864.0  8:30 am        50                  New York Pilates
# 6        4.8  41488.0  8:30 am        45  Flywheel Sports: Stadium Cycling
# 8        4.8  23958.0  8:30 am        55                  New York Pilates
# 10       4.7   7186.0  8:30 am        60                        ISHTA Yoga
# 13       4.8  37118.0  8:30 am        45                       Cyc Fitness
# 14       4.9   3651.0  8:30 am        45                         Shadowbox
# 15       4.8  14445.0  8:30 am        65                         Yoga Vida
# 16       4.8  10757.0  8:30 am        50                             Brrrn
# 17       4.8  60835.0  8:30 am        45  Flywheel Sports: Stadium Cycling
# 19       4.8   5581.0  8:30 am        60                YO BK Williamsburg
# 22       4.8   5608.0  8:30 am        60          Mark Morris Dance Center
# 26       4.9   3639.0  8:30 am        75                           Juniper
# 27       4.8  40591.0  8:30 am        45  Flywheel Sports: Stadium Cycling
# 29       4.8   3806.0  8:30 am        60                  Loom Yoga Center
# 31       4.8  44803.0  8:30 am        45  Flywheel Sports: Stadium Cycling
# 35       4.8  27676.0  8:30 am        45  Flywheel Sports: Stadium Cycling
# 38       4.8    354.0  8:30 am        60               RIOULT Dance Center
# 38       4.8    354.0  8:30 am        60               RIOULT Dance Center
# 39       4.8   9267.0  8:30 am        60                 Five Pillars Yoga
# 40       4.6      5.0  8:30 am        60                    Mind Your Body
# 43       4.6    347.0  8:30 am        30            Vigorous Fitness Clubs
# 44       4.9    263.0  8:30 am        40                      IM=X Pilates
# 45       4.8    292.0  8:30 am        60                       IMX Pilates
# 47       4.7    392.0  8:30 am        45                         REV Cycle
# 52       4.8     45.0  8:30 am        50             Woodmere Fitness Club
# 53       5.0     82.0  8:30 am        50                     JBARRE STUDIO
# ...      ...      ...      ...       ...                               ...
# 2411     4.8    521.0  7:30 pm        75          Sweet Water Dance & Yoga
# 2412     4.3     29.0  7:30 pm        60        Above All Fitness Fort Lee
# 2418     4.9   1075.0  7:30 pm        75                              Zura
# 2425     4.5     41.0  7:30 pm        60                Juluka Yoga Studio
# 2428     4.8     30.0  7:35 pm        50                    StripXpertease
# 2429     4.6     32.0  7:40 pm        45                 Dance With Me USA
# 2430     4.6  10972.0  7:45 pm        60                         YogaWorks
# 2431     4.8  46649.0  7:45 pm        45             Overthrow Boxing Club
# 2434     4.7   7186.0  7:45 pm        75                        ISHTA Yoga
# 2436     4.8  26750.0  7:45 pm        65                         Yoga Vida
# 2437     4.9   2480.0  7:45 pm        75                       IncrediPole
# 2438     4.8   5608.0  7:45 pm        90          Mark Morris Dance Center
# 2443     4.7  21564.0  8:00 pm        60             Pilates on the Square
# 2444     4.7  21564.0  8:00 pm        60             Pilates on the Square
# 2450     4.9   4831.0  8:00 pm        60                    usha veda yoga
# 2451     4.7   7531.0  8:00 pm        75            Park Slope Yoga Center
# 2454     4.8  11343.0  8:00 pm        90                   Jewel City Yoga
# 2457     4.5   2499.0  8:00 pm        75                         Naam Yoga
# 2460     4.6    347.0  8:00 pm        30            Vigorous Fitness Clubs
# 2463     4.7     30.0  8:00 pm        60                    Fit Body Workx
# 2464     4.6     35.0  8:00 pm        60                    Tapout Fitness
# 2465     4.8    155.0  8:00 pm        75                 Shiva Shanti Yoga
# 2467     4.8     76.0  8:00 pm        60                        Studio Air
# 2470     4.6   2900.0  8:10 pm        60               Atmananda East 23rd
# 2473     4.9   1604.0  8:15 pm        75                        YES Studio
# 2477     4.8   4542.0  8:30 pm        60             Foxy Fitness and Pole
# 2478     4.6    347.0  8:30 pm        30            Vigorous Fitness Clubs
# 2484     4.6    347.0  9:00 pm        30            Vigorous Fitness Clubs
# 2486     4.5   2499.0  9:15 pm        90                         Naam Yoga
# 2487     4.6    347.0  9:30 pm        30            Vigorous Fitness Clubs
#
#                location      tags  price
# 0                  SoHo   Pilates     25
# 1               Tribeca      Yoga     11
# 2                  SoHo   Pilates     16
# 3                  SoHo      Yoga      4
# 4                Bowery   Pilates     25
# 6               Tribeca   Cycling     13
# 8     Greenwich Village   Pilates     25
# 10    Greenwich Village      Yoga      6
# 13              Chelsea   Cycling     10
# 14                DUMBO    Boxing     18
# 15                DUMBO      Yoga      5
# 16             Flatiron    Boxing      8
# 17             Flatiron   Cycling     12
# 19         Williamsburg      Yoga     11
# 22          Fort Greene     Dance     10
# 26     Prospect Heights      Yoga      5
# 27      Upper East Side   Cycling     12
# 29             Bushwick      Yoga      8
# 31      Upper West Side   Cycling     15
# 35      Upper West Side   Cycling     12
# 38     Long Island City      Yoga      5
# 38     Long Island City   Pilates      5
# 39      Upper East Side      Yoga      8
# 40           Ozone Park   Pilates     10
# 43       Middle Village   Cycling      4
# 44            Englewood   Pilates      9
# 45              Clifton   Pilates      8
# 47              Yonkers   Cycling      5
# 52           Cedarhurst    Boxing      4
# 53             Caldwell   Pilates      4
# ...                 ...       ...    ...
# 2411  Concourse Village      Yoga      4
# 2412          Englewood     Dance      1
# 2418          Montclair      Yoga      3
# 2425          Cresskill      Yoga      1
# 2428   Garment District     Dance      6
# 2429     Hell's Kitchen     Dance      6
# 2430               SoHo      Yoga      8
# 2431               NoHo    Boxing      9
# 2434  Greenwich Village      Yoga      6
# 2436  Greenwich Village      Yoga      6
# 2437         Greenpoint     Dance      9
# 2438        Fort Greene     Dance     10
# 2443       Union Square   Pilates     10
# 2444       Union Square   Pilates     10
# 2450         Greenpoint      Yoga      4
# 2451         Park Slope      Yoga      6
# 2454      Crown Heights      Yoga      4
# 2457    Upper West Side      Yoga      6
# 2460     Middle Village   Cycling      4
# 2463           Harrison    Boxing      3
# 2464         Ozone Park     Dance      1
# 2465         Rutherford      Yoga      3
# 2467          Montclair     Dance      4
# 2470      Gramercy Park      Yoga      5
# 2473          Ridgewood      Yoga      3
# 2477            Chelsea     Dance      6
# 2478     Middle Village   Cycling      4
# 2484     Middle Village   Cycling      4
# 2486    Upper West Side      Yoga      6
# 2487     Middle Village   Cycling      4
#
# [1228 rows x 10 columns]

# %%
idx = genres.groupby('tags').median()['price'].sort_values(ascending=False).index
sns.boxplot(x='tags', y='price', data=genres,order = idx)
plt.xlabel('Genre')
plt.ylabel('Price')
plt.title('Genre specific pricing', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Genre specific pricing')

# %%
genre_price.sort_values(ascending=False).plot(kind='bar', color="#264bec")
plt.xlabel('Genre')
plt.ylabel('Average price')
plt.title('Genre specific pricing', fontsize=18)
print(genre_price)
# Out:
# tags
#  Boxing      8.412371
#  Cycling     8.393548
#  Dance       6.486486
#  Pilates    10.235521
#  Yoga        6.211221
# Name: price, dtype: float64

# %%
genres#.sort_values('tags',ascending = False)
# Out:
#                                               title           instructor  \
# 0                    Pilates Reformer: Abs Arms Ass           Meg Broome
# 1                                     SKY TING Yoga         Grace Dubery
# 2                                  WundaBar Workout      Marta Picaporte
# 3                                       BigToe Flow     Patrick Rafferty
# 4                         Pilates Reformer: Burnout         Lisa Jantzie
# 6                               Flywheel: Method 45         Cedric Green
# 8                Pilates Reformer: Sculpt + Restore          Heran Haile
# 10                                    ISHTA Vinyasa       Mikaela Soldan
# 13                                            Cyc45      Michael Clement
# 14                             SHADOWBOX - STANDARD              Brendan
# 15                                      Heated Flow            Amy Wolfe
# 16                                              HIT        Scott Freeman
# 17                              Flywheel: Method 45        Steven Little
# 19                           Bikram Yoga 60 - Music       Sara Corenzwit
# 22                               Adult: Gaga.People        Gaga *Faculty
# 26                                         Prenatal         Sonia Reiter
# 27                              Flywheel: Method 45       Nowani Rattray
# 29                                         All Flow         Natalie Girs
# 31                      Flywheel: Method 45 - #FBF!     Garret Caillouet
# 35                              Flywheel: Method 45        Bryan Jarrett
# 38                                      Gyrokinesis            Ezhra Goh
# 38                                      Gyrokinesis            Ezhra Goh
# 39                                 Five Pillars 360        Lauren Harris
# 40                                         REFORMER          Sam Mitrani
# 43                              PELOTON RESERVATION            PELOTON .
# 44           IM=X Pilates Basic Xercizer - BEGINNER       BettyAnn Niece
# 45                     IM=X Inter/Advanced Xercizer  Dr. Michael Magwood
# 47                                      Rev Rhythms     Kathleen Tobacco
# 52                                  Kickboxing Plus        Deena Warshaw
# 53                                     BARRE SCULPT      JonnaLyn Panico
# ...                                             ...                  ...
# 2411                                    YOGA: Hatha           Nyota Nayo
# 2412                                          Zumba              Crystal
# 2418                                       Yin Yoga       Christi Himiob
# 2425                                 Community Yoga      Juluka Teachers
# 2428        STRIPPER STRENGTH: Splits S-t-r-e-t-c-h                 KZ D
# 2429    Ladies Technique and Styling in Cha Cha Cha                Mandy
# 2430                           Restorative w/ Music      Alystyre Julian
# 2431                   Overthrow Underground Boxing            Julian D.
# 2434                          Candlelit Restorative      Donald Johnston
# 2436                                  Flow + Let Go        Allie Gardner
# 2437      Russian Exotic *PREREQUISITE BEGINNER II*   Casey Leigh Jordan
# 2438                 Adult: Open Level West African      Ismael *Kouyate
# 2443                         Pilates Machine Class.   Natalie Labellarte
# 2444                          Pilates Machine Class    Cassie Washington
# 2450  Restorative & Yoga Nidra Meditation (Level 1)         Christie Roe
# 2451                        Basic Vinyasa + Restore          Dana Greene
# 2454                                 Flow & Restore       Emily Nachazel
# 2457                              Naam Aromatherapy           Dallas Lyn
# 2460                            PELOTON RESERVATION            PELOTON .
# 2463                              Cardio Kickboxing         Diego Araujo
# 2464                                   Tapout Dance     Natalie Palomino
# 2465                    *Gentle Yoga and Meditation              Sam Kim
# 2467                     Backstage - Intro to Heels       Jazz The Poler
# 2470                                Candle-lit Yoga            Rose Luma
# 2473                                        YES Yin         Robyn Brooke
# 2477                         POLE (Tricks & Climbs)      Foxy Instructor
# 2478                            PELOTON RESERVATION            PELOTON .
# 2484                            PELOTON RESERVATION            PELOTON .
# 2486                          Full Moon Celebration           Dallas Lyn
# 2487                            PELOTON RESERVATION            PELOTON .
#
#       rating  reviews     time  duration                             venue  \
# 0        4.9  26215.0  8:30 am        55                  New York Pilates
# 1        4.8  17389.0  8:30 am        60                          SKY TING
# 2        4.8  19814.0  8:30 am        45                  WundaBar Pilates
# 3        4.8   2394.0  8:30 am        60                       BigToe Yoga
# 4        4.9  37864.0  8:30 am        50                  New York Pilates
# 6        4.8  41488.0  8:30 am        45  Flywheel Sports: Stadium Cycling
# 8        4.8  23958.0  8:30 am        55                  New York Pilates
# 10       4.7   7186.0  8:30 am        60                        ISHTA Yoga
# 13       4.8  37118.0  8:30 am        45                       Cyc Fitness
# 14       4.9   3651.0  8:30 am        45                         Shadowbox
# 15       4.8  14445.0  8:30 am        65                         Yoga Vida
# 16       4.8  10757.0  8:30 am        50                             Brrrn
# 17       4.8  60835.0  8:30 am        45  Flywheel Sports: Stadium Cycling
# 19       4.8   5581.0  8:30 am        60                YO BK Williamsburg
# 22       4.8   5608.0  8:30 am        60          Mark Morris Dance Center
# 26       4.9   3639.0  8:30 am        75                           Juniper
# 27       4.8  40591.0  8:30 am        45  Flywheel Sports: Stadium Cycling
# 29       4.8   3806.0  8:30 am        60                  Loom Yoga Center
# 31       4.8  44803.0  8:30 am        45  Flywheel Sports: Stadium Cycling
# 35       4.8  27676.0  8:30 am        45  Flywheel Sports: Stadium Cycling
# 38       4.8    354.0  8:30 am        60               RIOULT Dance Center
# 38       4.8    354.0  8:30 am        60               RIOULT Dance Center
# 39       4.8   9267.0  8:30 am        60                 Five Pillars Yoga
# 40       4.6      5.0  8:30 am        60                    Mind Your Body
# 43       4.6    347.0  8:30 am        30            Vigorous Fitness Clubs
# 44       4.9    263.0  8:30 am        40                      IM=X Pilates
# 45       4.8    292.0  8:30 am        60                       IMX Pilates
# 47       4.7    392.0  8:30 am        45                         REV Cycle
# 52       4.8     45.0  8:30 am        50             Woodmere Fitness Club
# 53       5.0     82.0  8:30 am        50                     JBARRE STUDIO
# ...      ...      ...      ...       ...                               ...
# 2411     4.8    521.0  7:30 pm        75          Sweet Water Dance & Yoga
# 2412     4.3     29.0  7:30 pm        60        Above All Fitness Fort Lee
# 2418     4.9   1075.0  7:30 pm        75                              Zura
# 2425     4.5     41.0  7:30 pm        60                Juluka Yoga Studio
# 2428     4.8     30.0  7:35 pm        50                    StripXpertease
# 2429     4.6     32.0  7:40 pm        45                 Dance With Me USA
# 2430     4.6  10972.0  7:45 pm        60                         YogaWorks
# 2431     4.8  46649.0  7:45 pm        45             Overthrow Boxing Club
# 2434     4.7   7186.0  7:45 pm        75                        ISHTA Yoga
# 2436     4.8  26750.0  7:45 pm        65                         Yoga Vida
# 2437     4.9   2480.0  7:45 pm        75                       IncrediPole
# 2438     4.8   5608.0  7:45 pm        90          Mark Morris Dance Center
# 2443     4.7  21564.0  8:00 pm        60             Pilates on the Square
# 2444     4.7  21564.0  8:00 pm        60             Pilates on the Square
# 2450     4.9   4831.0  8:00 pm        60                    usha veda yoga
# 2451     4.7   7531.0  8:00 pm        75            Park Slope Yoga Center
# 2454     4.8  11343.0  8:00 pm        90                   Jewel City Yoga
# 2457     4.5   2499.0  8:00 pm        75                         Naam Yoga
# 2460     4.6    347.0  8:00 pm        30            Vigorous Fitness Clubs
# 2463     4.7     30.0  8:00 pm        60                    Fit Body Workx
# 2464     4.6     35.0  8:00 pm        60                    Tapout Fitness
# 2465     4.8    155.0  8:00 pm        75                 Shiva Shanti Yoga
# 2467     4.8     76.0  8:00 pm        60                        Studio Air
# 2470     4.6   2900.0  8:10 pm        60               Atmananda East 23rd
# 2473     4.9   1604.0  8:15 pm        75                        YES Studio
# 2477     4.8   4542.0  8:30 pm        60             Foxy Fitness and Pole
# 2478     4.6    347.0  8:30 pm        30            Vigorous Fitness Clubs
# 2484     4.6    347.0  9:00 pm        30            Vigorous Fitness Clubs
# 2486     4.5   2499.0  9:15 pm        90                         Naam Yoga
# 2487     4.6    347.0  9:30 pm        30            Vigorous Fitness Clubs
#
#                location      tags  price
# 0                  SoHo   Pilates     25
# 1               Tribeca      Yoga     11
# 2                  SoHo   Pilates     16
# 3                  SoHo      Yoga      4
# 4                Bowery   Pilates     25
# 6               Tribeca   Cycling     13
# 8     Greenwich Village   Pilates     25
# 10    Greenwich Village      Yoga      6
# 13              Chelsea   Cycling     10
# 14                DUMBO    Boxing     18
# 15                DUMBO      Yoga      5
# 16             Flatiron    Boxing      8
# 17             Flatiron   Cycling     12
# 19         Williamsburg      Yoga     11
# 22          Fort Greene     Dance     10
# 26     Prospect Heights      Yoga      5
# 27      Upper East Side   Cycling     12
# 29             Bushwick      Yoga      8
# 31      Upper West Side   Cycling     15
# 35      Upper West Side   Cycling     12
# 38     Long Island City      Yoga      5
# 38     Long Island City   Pilates      5
# 39      Upper East Side      Yoga      8
# 40           Ozone Park   Pilates     10
# 43       Middle Village   Cycling      4
# 44            Englewood   Pilates      9
# 45              Clifton   Pilates      8
# 47              Yonkers   Cycling      5
# 52           Cedarhurst    Boxing      4
# 53             Caldwell   Pilates      4
# ...                 ...       ...    ...
# 2411  Concourse Village      Yoga      4
# 2412          Englewood     Dance      1
# 2418          Montclair      Yoga      3
# 2425          Cresskill      Yoga      1
# 2428   Garment District     Dance      6
# 2429     Hell's Kitchen     Dance      6
# 2430               SoHo      Yoga      8
# 2431               NoHo    Boxing      9
# 2434  Greenwich Village      Yoga      6
# 2436  Greenwich Village      Yoga      6
# 2437         Greenpoint     Dance      9
# 2438        Fort Greene     Dance     10
# 2443       Union Square   Pilates     10
# 2444       Union Square   Pilates     10
# 2450         Greenpoint      Yoga      4
# 2451         Park Slope      Yoga      6
# 2454      Crown Heights      Yoga      4
# 2457    Upper West Side      Yoga      6
# 2460     Middle Village   Cycling      4
# 2463           Harrison    Boxing      3
# 2464         Ozone Park     Dance      1
# 2465         Rutherford      Yoga      3
# 2467          Montclair     Dance      4
# 2470      Gramercy Park      Yoga      5
# 2473          Ridgewood      Yoga      3
# 2477            Chelsea     Dance      6
# 2478     Middle Village   Cycling      4
# 2484     Middle Village   Cycling      4
# 2486    Upper West Side      Yoga      6
# 2487     Middle Village   Cycling      4
#
# [1228 rows x 10 columns]

# %%
# genres_simple = genres.loc[genres.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)] #if they are both less than 3 standard deviations then we keep them, otherwise drop
# from scipy import stats
# genres[(np.abs(stats.zscore(df)) < 3).reviews(axis=1)]
genres_simple= genres[np.abs(genres.reviews-genres.reviews.mean()) <= (2*genres.reviews.std())]

idx = genres_simple.groupby('tags').mean()['reviews'].sort_values(ascending=False).index #note what is it ordered by
sns.boxplot(x='tags', y='reviews', data=genres_simple,order = idx)
plt.xlabel('Genre')
plt.ylabel('Popularity')
plt.title('Genre specific popularity', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Genre specific popularity')

# %%
genre_reviews.sort_values(ascending=False).plot(kind='bar', color="#264bec")
plt.xlabel('Genre')
plt.ylabel('Average number of reviews')
plt.title('Genre specific popularity', fontsize=18)
print(genre_reviews)
# Out:
# tags
#  Boxing     10994.484536
#  Cycling    21280.464516
#  Dance       4725.279279
#  Pilates    10710.656371
#  Yoga        8057.325083
# Name: reviews, dtype: float64

# %%
idx = genres.groupby('tags').median()['duration'].sort_values(ascending=False).index
sns.boxplot(x='tags', y='duration', data=genres,order = idx)
plt.xlabel('Genre')
plt.ylabel('Duration')
plt.title('Genre specific class duration', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Genre specific class duration')

# %%
genre_durat.sort_values(ascending=False).plot(kind='bar', color="#264bec")
plt.xlabel('Genre')
plt.ylabel('Average class duration')
plt.title('Genre specific duration', fontsize=18)
print(genre_durat)
# Out:
# tags
#  Boxing     52.381443
#  Cycling    42.993548
#  Dance      67.252252
#  Pilates    54.498069
#  Yoga       67.059406
# Name: duration, dtype: float64

# %%
rat_pri = df[['rating','price','reviews']] #attempt to observe the relationship between class price and its rating

# %%
rat_pri.plot(kind='scatter', x='rating',y='price',s = 50,c='reviews',cmap="plasma")
plt.title("Class price against rating")
plt.xlabel("Rating")
plt.ylabel("Class price")
plt.show()

# %%
fig = plt.figure() # Create matplotlib figure
fig.set_size_inches(18.5, 10.5)
# rat_pri.plot(kind='scatter', x='rating',y='price',s = 50,c='reviews',cmap="plasma")
plt.scatter(x=rat_pri['rating'],y=rat_pri['price'],s = 50,c=rat_pri['reviews'],cmap="plasma")


plt.title("Class price against rating",fontsize =20)
plt.xlabel("Rating",fontsize = 18)
plt.ylabel("Class price",fontsize = 18)
plt.show()

# %%
rat_rev = df[['rating','reviews']] #attempt to observe the relationship between number of reviews and rating
rat_rev.plot.scatter('rating','reviews')

# %%
print(df.price.mean())
print(df.rating.mean())
print(df.reviews.mean())
print(df.duration.mean())
# Out:
# 8.0207991242474
# 4.7899835796387356
# 11984.585112205801
# 58.20361247947455

# %%
grouped_venue = df.groupby(['venue','location']).mean() #grouping dataframe by the different gyms
grouped_venue['expensive?'] =(grouped_venue['price']>8.02) #is it expensive?
grouped_venue['highly rated?'] =(grouped_venue['rating']>4.79) #is it highly rated?
grouped_venue['popular?'] =(grouped_venue['reviews']>11984.6) #is it highly rated?
grouped_venue['long?'] =(grouped_venue['duration']>58.2) #is it highly rated?
cleaned_gv = grouped_venue.round(1).sort_values('reviews',ascending=False).head(12)#.mean()['price']
cleaned_gv.drop(['rating', 'reviews','duration','price'], axis=1)
#try using heatmap from plotly - assigning the colour to each value
# Out:
#                                                   expensive?  highly rated?  \
# venue                            location
# Flywheel Sports: Stadium Cycling East Village           True           True
# Mile High Run Club               NoMad                  True           True
# Peloton Cycling Studio           Chelsea                True           True
# Mile High Run Club               NoHo                   True           True
# Flywheel Sports: Stadium Cycling Flatiron               True           True
# Physique 57                      SoHo                   True           True
# Flywheel Sports: Stadium Cycling NoMad                  True           True
# Switch Playground USA            Union Square           True           True
# Flywheel Sports: Stadium Cycling Chelsea                True           True
# Physique 57                      Upper West Side        True           True
# Y7 Studio                        Upper East Side        True           True
# Physique 57                      Midtown                True           True
#
#                                                   popular?  long?
# venue                            location
# Flywheel Sports: Stadium Cycling East Village         True  False
# Mile High Run Club               NoMad                True  False
# Peloton Cycling Studio           Chelsea              True  False
# Mile High Run Club               NoHo                 True  False
# Flywheel Sports: Stadium Cycling Flatiron             True  False
# Physique 57                      SoHo                 True   True
# Flywheel Sports: Stadium Cycling NoMad                True  False
# Switch Playground USA            Union Square         True  False
# Flywheel Sports: Stadium Cycling Chelsea              True  False
# Physique 57                      Upper West Side      True   True
# Y7 Studio                        Upper East Side      True   True
# Physique 57                      Midtown              True   True

# %%
import seaborn as sns
lm = sns.lmplot("price", "reviews", data = df,line_kws={'color': 'red'},fit_reg = True,scatter_kws={'facecolors':'blue'})
lm = lm.set_axis_labels("Price", "Popularity")
fig = lm.fig
fig.suptitle("Price & Popularity relationship", fontsize=18)
lm.fig.subplots_adjust(top=.9)
