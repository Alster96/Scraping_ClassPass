# %% [markdown]
# Project 1 - Classpass data analysis

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('thursday_classpass.csv',encoding = 'unicode_escape')
df.sample(10)
# Out:
#                                      Title     Instructor Rating Reviews  \
# 1059                              Gym Time           none    4.6  12,924
# 466                            SHAKTIBARRE    Chloe Crade    4.9   1,309
# 693                           Zumba Toning        Michele    4.8     218
# 583            45-Minute Sensory 7 Session           none    4.5   1,057
# 950                          Vixen Workout           none   none    none
# 984                    Group Fitness Class           none    4.9       6
# 883                           Aahh PUSH IT      Ian Boyce   none    none
# 988                                Dad Bod           none    4.6      23
# 421                   FlyBarre: Classic 60  Lane Halperin    4.8  18,737
# 650   Kickboxing (Advanced & Intermediate)          Mr. C    4.7     598
#
#          Time  Duration                                Venue         Location  \
# 1059  8:00 pm       120                           Crunch Gym  Upper East Side
# 466   6:30 pm        55                          SHAKTIBARRE           Harlem
# 693   7:00 pm        60                 ConfiDanZe & Fitness       Great Neck
# 583   7:00 pm        45                      Modrn Sanctuary            NoMad
# 950   7:30 pm        60              Vixen Workout With Nati              NaN
# 984   7:30 pm        45                          CMA Fitness         Roseland
# 883   7:30 pm        60           K.S. J.A.M.M. Dance Troupe              NaN
# 988   7:30 pm        60                          JNA Fitness              NaN
# 421   6:30 pm        60  Flywheel Sports: Precision Training  Upper East Side
# 650   7:00 pm        45             Valor Mixed Martial Arts  Upper West Side
#
#                                                    Tags  Price
# 1059                                                NaN      3
# 466   Relaxation, Flexibility, Balance, Core, Abs, B...      8
# 693                 Cardio, Flexibility, Balance, Dance      1
# 583                                                 NaN     29
# 950                                               Dance      1
# 984                                   Strength Training      4
# 883                                   Strength Training      4
# 988                                                 NaN      4
# 421              Flexibility, Balance, Core, Abs, Barre     14
# 650                                                 NaN      9

# %%
df.corr()
# Out:
#           Duration     Price
# Duration  1.000000 -0.206172
# Price    -0.206172  1.000000

# %%
df.dtypes
# Out:
# Title         object
# Instructor    object
# Rating        object
# Reviews       object
# Time          object
# Duration       int64
# Venue         object
# Location      object
# Tags          object
# Price          int64
# dtype: object

# %%
df.columns = df.columns.str.lower()
df.sample(10)
# Out:
#                                 title       instructor rating reviews  \
# 1119  Hip Hop Wednesdays Vinyasa Yoga       Sam Garcia    4.8  33,294
# 401                      Vinyasa Flow       Sean Moore    4.9     538
# 687                     Beginner Pole         Allie M.    4.8      76
# 439                Total Body Circuit    Reggie Cooley    4.7   2,939
# 408          Total Body Circuit 50/10    Mike Montanez      5  12,546
# 91                        Signature I   Emily W. Wolff    4.9  47,321
# 755    INTRODUCTION TO YOGA & VINYASA  Jordan Marciano    4.9      81
# 324                Mind Body Bootcamp  Brian Delmonico    4.8  16,890
# 1039                       Power Flow       Josh Meier    4.8   6,268
# 152                Plushfit-Arms, Abs    Phillip Shinn    4.7   2,441
#
#          time  duration                             venue          location  \
# 1119  8:15 pm        60                         Y7 Studio              SoHo
# 401   6:30 pm        68                   Swans Nest Yoga      Williamsburg
# 687   7:00 pm        60                        Studio Air         Montclair
# 439   6:30 pm        45                     Regenerate 82   Upper East Side
# 408   6:30 pm        60           Tabata Ultimate Fitness  Prospect Heights
# 91    5:30 pm        60                       Physique 57           Midtown
# 755   7:15 pm        75                   Good Vibes Yoga               NaN
# 324   6:30 pm        50  Circuit of Change - Union Square      Union Square
# 1039  7:45 pm        60                     The Yoga Room           Astoria
# 152   5:35 pm        55                     Plush Fitness             NoMad
#
#                                               tags  price
# 1119              Flexibility, Balance, Arms, Yoga     10
# 401   Relaxation, Flexibility, Balance, Arms, Yoga      7
# 687            Cardio, Flexibility, Balance, Dance      4
# 439                              Strength Training     11
# 408                              Strength Training     10
# 91          Flexibility, Balance, Core, Abs, Barre     12
# 755                                           Yoga      3
# 324                              Strength Training     10
# 1039              Flexibility, Balance, Arms, Yoga      9
# 152                              Strength Training      7
